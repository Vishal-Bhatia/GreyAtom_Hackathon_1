# %% [markdown]
# # Sales report using Pandas
# ***
# ## Problem Statement
#
# Hello budding Data Scientists. We have with us a bank data set which gives information about the revenue of various customers spread across different regions in USA.
#
# Using the knowledge of Pandas and Matplotlib, we will try to answer certain questions from the bank dataset
#
# We will also then scrape certain additional data from Wikipedia, clean it and combine it with our bank data for better understandability of the data.
#
#
# ## About the Dataset
#
# Preview of the dataset
#
# ![bank_dataset](../images/bank_data.png)
#
# The dataset has details of 15 customers with following 9 features.
#
# |Feature|Description|
# |-----|-----|
# |account|account Id|
# |name|name of the person|
# |street|Name of the street|
# |city|Name of the city|
# |state|Name of the state|
# |postal-code|numerical value|
# |Jan|Amount in doller|
# |Feb|Amount in doller|
# |Mar|Amount in doller|
#
#
#
#
# ## Why solve this project
#
# Doing this project will enable you to integrate Multiple data sources to answer basic questions. You will also learn to perform common excel tasks with pandas
#
# What will you learn in the session ?
# Python Basics
# Pandas
# Web Scrapping
# Functions
# Plotting
# Pre-requisites
# Working knowledge of Pandas, Numpy, Matplotlib
# Data indexing and slicing

# %% [markdown]
# # Load Data and Compute total
# The first step - you know the drill by now - load the dataset and see how it looks like. Additionally, calculate the total amount in the first quarter of the financial year. Calculate the total amount of all the users for the month of jan, feb and Mar and also grand total.
#
#
# ## Instructions
#
# - Load dataset using pandas read_csv api in variable `df` and give file path as `path`.
# - The names of the states `state` column are changed to lower case and store it in `df['state']`
# - Create a new column named `total` which computes the total amount in the first quarter
#   of the financial year i.e. for the months of Jan, Feb and Mar and store it in `df['total']`
# - Calculate the sum of amount of all users in the Month of Jan, Feb, March and store it in variable `sum_row`
#  (Here the sum implies the sum of all the entries in the `Jan Column`, sum of entries in `Feb` Column and Grand total stands for the sum of entries in the column `total`)
# - Append this computed sum to the DataFrame `df_final`

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Code starts here
path="excel-comp-data.csv"
df=pd.read_csv(path)
df["state"]=df["state"].str.lower()
df["total"]=df["Jan"]+df["Feb"]+df["Mar"]
sum_Jan=df["Jan"].sum()
sum_Feb=df["Feb"].sum()
sum_Mar=df["Mar"].sum()
sum_Total=df["total"].sum()
df_final = df.append([{'Jan':sum_Feb,"Feb":sum_Feb,"Mar":sum_Mar,"total":sum_Total}], ignore_index=True)
df_final
#Code ends here
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#      account                              name  \
# 0   211829.0        Kerluke, Koepp and Hilpert
# 1   320563.0                    Walter-Trantow
# 2   648336.0        Bashirian, Kunde and Price
# 3   109996.0       D'Amore, Gleichner and Bode
# 4   121213.0                     Bauch-Goldner
# 5   132971.0  Williamson, Schumm and Hettinger
# 6   145068.0                        Casper LLC
# 7   205217.0                  Kovacek-Johnston
# 8   209744.0                    Champlin-Morar
# 9   212303.0                    Gerhold-Maggio
# 10  214098.0       Goodwin, Homenick and Jerde
# 11  231907.0                        Hahn-Moore
# 12  242368.0      Frami, Anderson and Donnelly
# 13  268755.0                       Walsh-Haley
# 14  273274.0                     McDermott PLC
# 15       NaN                               NaN
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          texas
# 1                      1311 Alvis Tunnel      Port Khadijah  northcarolina
# 2   62184 Schamberger Underpass Apt. 231     New Lilianland           iowa
# 3            155 Fadel Crescent Apt. 144         Hyattburgh          maine
# 4                    7274 Marissa Common    Shanahanchester     california
# 5                   89403 Casimer Spring       Jeremieburgh       arkansas
# 6           340 Consuela Bridge Apt. 400  Lake Gabriellaton     mississipi
# 7           91971 Cronin Vista Suite 601         Deronville    rhodeisland
# 8                       26739 Grant Lock    Lake Juliannton   pennsylvania
# 9              366 Maggio Grove Apt. 998          North Ras          idaho
# 10             649 Cierra Forks Apt. 078           Rosaberg       tenessee
# 11              18115 Olivine Throughway      Norbertomouth    northdakota
# 12                       182 Bertie Road        East Davian           iowa
# 13                  2624 Beatty Parkways       Goodwinmouth    rhodeisland
# 14                 8917 Bergstrom Meadow    Kathryneborough       delaware
# 15                                   NaN                NaN            NaN
#
#     postal-code      Jan      Feb     Mar    total
# 0       28752.0    10000    62000   35000   107000
# 1       38365.0    95000    45000   35000   175000
# 2       76517.0    91000   120000   35000   246000
# 3       46021.0    45000   120000   10000   175000
# 4       49681.0   162000   120000   35000   317000
# 5       62785.0   150000   120000   35000   305000
# 6       18008.0    62000   120000   70000   252000
# 7       53461.0   145000    95000   35000   275000
# 8       64415.0    70000    95000   35000   200000
# 9       46308.0    70000   120000   35000   225000
# 10      47743.0    45000   120000   55000   220000
# 11      31415.0   150000    10000  162000   322000
# 12      72686.0   162000   120000   35000   317000
# 13      31919.0    55000   120000   35000   210000
# 14      27933.0   150000   120000   70000   340000
# 15          NaN  1507000  1507000  717000  3686000

# %% [markdown]
# # Scrape Data From the web
#
# Here, you will be scraping data from the web and cleaning it.
#
#
# ## Instructions:
#
# - Scrapes the url `https://en.wikipedia.org/wiki/List_of_U.S._state_abbreviations` and store it in variable `url`
# - Use module `requests` to `get` the url and store it in variable called `response`
# - load the html file in dataframe `df1`. `Note`:use `pd.read_html(response.content)[0]`.
# - First few rows consists of unclean data. You need to select rows from index 11 till end. Make the values at index 11 as column headers and store it in dataframe `df1`.
# - Remove space from the column named 'United States of America' and store the result in dataframe called `df1['United States of America']`

# %%
import requests

# Code starts here
url="https://en.wikipedia.org/wiki/List_of_U.S._state_abbreviations"
response=requests.get(url)
df1=pd.read_html(response.content)[0]
df1

# Code ends here
# Out:
#                                                    0   \
# 0   Codes:  ISO ISO 3166 codes (2-letter, 3-letter...
# 1                                              Codes:
# 2                                                 ISO
# 3                                                ANSI
# 4                                                USPS
# 5                                                USCG
# 6                                      Abbreviations:
# 7                                                 GPO
# 8                                                  AP
# 9                           Name and status of region
# 10                                                NaN
# 11                           United States of America
# 12                                            Alabama
# 13                                             Alaska
# 14                                            Arizona
# 15                                           Arkansas
# 16                                         California
# 17                                           Colorado
# 18                                        Connecticut
# 19                                           Delaware
# 20                               District of Columbia
# 21                                            Florida
# 22                                            Georgia
# 23                                             Hawaii
# 24                                              Idaho
# 25                                           Illinois
# 26                                            Indiana
# 27                                               Iowa
# 28                                             Kansas
# 29                                           Kentucky
# ..                                                ...
# 67                                U.S. Virgin Islands
# 68                        U.S. Minor Outlying Islands
# 69                                       Baker Island
# 70                                     Howland Island
# 71                                      Jarvis Island
# 72                                     Johnston Atoll
# 73                                       Kingman Reef
# 74                                     Midway Islands
# 75                                     Navassa Island
# 76                                   Palmyra Atoll[c]
# 77                                        Wake Island
# 78                                         Micronesia
# 79                                   Marshall Islands
# 80                                              Palau
# 81                    U.S. Armed Forces – Americas[d]
# 82                      U.S. Armed Forces – Europe[e]
# 83                     U.S. Armed Forces – Pacific[f]
# 84                           Northern Mariana Islands
# 85                                  Panama Canal Zone
# 86                                           Nebraska
# 87                                 Philippine Islands
# 88             Trust Territory of the Pacific Islands
# 89                                             Codes:
# 90                                                ISO
# 91                                               ANSI
# 92                                               USPS
# 93                                               USCG
# 94                                     Abbreviations:
# 95                                                GPO
# 96                                                 AP
#
#                                                    1   \
# 0                                              Codes:
# 1                                                 NaN
# 2   ISO 3166 codes (2-letter, 3-letter, and 3-digi...
# 3   2-letter and 2-digit codes from the ANSI stand...
# 4   2-letter codes used by the United States Posta...
# 5   2-letter codes used by the United States Coast...
# 6                                                 NaN
# 7   Older variable-length official US Government P...
# 8   Abbreviations from the AP Stylebook (red text ...
# 9                                                 ISO
# 10                                                NaN
# 11                                      Federal state
# 12                                              State
# 13                                              State
# 14                                              State
# 15                                              State
# 16                                              State
# 17                                              State
# 18                                              State
# 19                                              State
# 20                                   Federal district
# 21                                              State
# 22                                              State
# 23                                              State
# 24                                              State
# 25                                              State
# 26                                              State
# 27                                              State
# 28                                              State
# 29                               State (Commonwealth)
# ..                                                ...
# 67                           Insular area (Territory)
# 68                                      Insular areas
# 69                                             island
# 70                                             island
# 71                                             island
# 72                                              atoll
# 73                                              atoll
# 74                                              atoll
# 75                                             island
# 76                                           atoll[c]
# 77                                              atoll
# 78                            Freely associated state
# 79                            Freely associated state
# 80                            Freely associated state
# 81                              US military mail code
# 82                              US military mail code
# 83                              US military mail code
# 84                            Obsolete postal code[g]
# 85                               Obsolete postal code
# 86                            Obsolete postal code[h]
# 87                               Obsolete postal code
# 88                               Obsolete postal code
# 89                                                NaN
# 90  ISO 3166 codes (2-letter, 3-letter, and 3-digi...
# 91  2-letter and 2-digit codes from the ANSI stand...
# 92  2-letter codes used by the United States Posta...
# 93  2-letter codes used by the United States Coast...
# 94                                                NaN
# 95  Older variable-length official US Government P...
# 96  Abbreviations from the AP Stylebook (red text ...
#
#                                                    2   \
# 0                                                 ISO
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                ANSI
# 10                                                NaN
# 11  .mw-parser-output .monospaced{font-family:mono...
# 12                                              US-AL
# 13                                              US-AK
# 14                                              US-AZ
# 15                                              US-AR
# 16                                              US-CA
# 17                                              US-CO
# 18                                              US-CT
# 19                                              US-DE
# 20                                              US-DC
# 21                                              US-FL
# 22                                              US-GA
# 23                                              US-HI
# 24                                              US-ID
# 25                                              US-IL
# 26                                              US-IN
# 27                                              US-IA
# 28                                              US-KS
# 29                                              US-KY
# ..                                                ...
# 67                                      VIVIR850US-VI
# 68                                      UMUMI581US-UM
# 69                                              UM-81
# 70                                              UM-84
# 71                                              UM-86
# 72                                              UM-67
# 73                                              UM-89
# 74                                              UM-71
# 75                                              UM-76
# 76                                              UM-95
# 77                                              UM-79
# 78                                           FMFSM583
# 79                                           MHMHL584
# 80                                           PWPLW585
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                           PZPCZ594
# 86                                                NaN
# 87                                        PHPHL608[4]
# 88                                           PCPCI582
# 89                                                NaN
# 90                                                NaN
# 91                                                NaN
# 92                                                NaN
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
#
#                                                    3     4   \
# 0   ISO 3166 codes (2-letter, 3-letter, and 3-digi...  ANSI
# 1                                                 NaN   NaN
# 2                                                 NaN   NaN
# 3                                                 NaN   NaN
# 4                                                 NaN   NaN
# 5                                                 NaN   NaN
# 6                                                 NaN   NaN
# 7                                                 NaN   NaN
# 8                                                 NaN   NaN
# 9                                                USPS  USCG
# 10                                                NaN   NaN
# 11                                                 US    00
# 12                                                 AL    01
# 13                                                 AK    02
# 14                                                 AZ    04
# 15                                                 AR    05
# 16                                                 CA    06
# 17                                                 CO    08
# 18                                                 CT    09
# 19                                                 DE    10
# 20                                                 DC    11
# 21                                                 FL    12
# 22                                                 GA    13
# 23                                                 HI    15
# 24                                                 ID    16
# 25                                                 IL    17
# 26                                                 IN    18
# 27                                                 IA    19
# 28                                                 KS    20
# 29                                                 KY    21
# ..                                                ...   ...
# 67                                                 VI    78
# 68                                                 UM    74
# 69                                                NaN    81
# 70                                                NaN    84
# 71                                                NaN    86
# 72                                                NaN    67
# 73                                                NaN    89
# 74                                                NaN    71
# 75                                                NaN    76
# 76                                                NaN    95
# 77                                                NaN    79
# 78                                                 FM    64
# 79                                                 MH    68
# 80                                                 PW    70
# 81                                                NaN   NaN
# 82                                                NaN   NaN
# 83                                                NaN   NaN
# 84                                                NaN   NaN
# 85                                                NaN   NaN
# 86                                                NaN   NaN
# 87                                                NaN   NaN
# 88                                                NaN   NaN
# 89                                                NaN   NaN
# 90                                                NaN   NaN
# 91                                                NaN   NaN
# 92                                                NaN   NaN
# 93                                                NaN   NaN
# 94                                                NaN   NaN
# 95                                                NaN   NaN
# 96                                                NaN   NaN
#
#                                                    5     6   \
# 0   2-letter and 2-digit codes from the ANSI stand...  USPS
# 1                                                 NaN   NaN
# 2                                                 NaN   NaN
# 3                                                 NaN   NaN
# 4                                                 NaN   NaN
# 5                                                 NaN   NaN
# 6                                                 NaN   NaN
# 7                                                 NaN   NaN
# 8                                                 NaN   NaN
# 9                                                 GPO    AP
# 10                                                NaN   NaN
# 11                                                NaN   NaN
# 12                                                 AL    AL
# 13                                                 AK    AK
# 14                                                 AZ    AZ
# 15                                                 AR    AR
# 16                                                 CA    CF
# 17                                                 CO    CL
# 18                                                 CT    CT
# 19                                                 DE    DL
# 20                                                 DC    DC
# 21                                                 FL    FL
# 22                                                 GA    GA
# 23                                                 HI    HA
# 24                                                 ID    ID
# 25                                                 IL    IL
# 26                                                 IN    IN
# 27                                                 IA    IA
# 28                                                 KS    KA
# 29                                                 KY    KY
# ..                                                ...   ...
# 67                                                 VI    VI
# 68                                                NaN   NaN
# 69                                                NaN   NaN
# 70                                                NaN   NaN
# 71                                                NaN   NaN
# 72                                                NaN   NaN
# 73                                                NaN   NaN
# 74                                                NaN   NaN
# 75                                                NaN   NaN
# 76                                                NaN   NaN
# 77                                                NaN   NaN
# 78                                                 FM   NaN
# 79                                                 MH   NaN
# 80                                                 PW   NaN
# 81                                                 AA   NaN
# 82                                                 AE   NaN
# 83                                                 AP   NaN
# 84                                                 CM   NaN
# 85                                                 CZ   NaN
# 86                                                 NB   NaN
# 87                                                 PI   NaN
# 88                                                 TT   NaN
# 89                                                NaN   NaN
# 90                                                NaN   NaN
# 91                                                NaN   NaN
# 92                                                NaN   NaN
# 93                                                NaN   NaN
# 94                                                NaN   NaN
# 95                                                NaN   NaN
# 96                                                NaN   NaN
#
#                                                    7       8   \
# 0   2-letter codes used by the United States Posta...    USCG
# 1                                                 NaN     NaN
# 2                                                 NaN     NaN
# 3                                                 NaN     NaN
# 4                                                 NaN     NaN
# 5                                                 NaN     NaN
# 6                                                 NaN     NaN
# 7                                                 NaN     NaN
# 8                                                 NaN     NaN
# 9                                  Otherabbreviations     NaN
# 10                                                NaN     NaN
# 11                                               U.S.    U.S.
# 12                                               Ala.    Ala.
# 13                                             Alaska  Alaska
# 14                                              Ariz.   Ariz.
# 15                                               Ark.    Ark.
# 16                                             Calif.  Calif.
# 17                                              Colo.   Colo.
# 18                                              Conn.   Conn.
# 19                                               Del.    Del.
# 20                                               D.C.    D.C.
# 21                                               Fla.    Fla.
# 22                                                Ga.     Ga.
# 23                                             Hawaii  Hawaii
# 24                                              Idaho   Idaho
# 25                                               Ill.    Ill.
# 26                                               Ind.    Ind.
# 27                                               Iowa    Iowa
# 28                                              Kans.    Kan.
# 29                                                Ky.     Ky.
# ..                                                ...     ...
# 67                                               V.I.     NaN
# 68                                                NaN     NaN
# 69                                                NaN     NaN
# 70                                                NaN     NaN
# 71                                                NaN     NaN
# 72                                                NaN     NaN
# 73                                                NaN     NaN
# 74                                                NaN     NaN
# 75                                                NaN     NaN
# 76                                                NaN     NaN
# 77                                                NaN     NaN
# 78                                                NaN     NaN
# 79                                                NaN     NaN
# 80                                                NaN     NaN
# 81                                                NaN     NaN
# 82                                                NaN     NaN
# 83                                                NaN     NaN
# 84                                                NaN     NaN
# 85                                                NaN     NaN
# 86                                                NaN     NaN
# 87                                                NaN     NaN
# 88                                                NaN     NaN
# 89                                                NaN     NaN
# 90                                                NaN     NaN
# 91                                                NaN     NaN
# 92                                                NaN     NaN
# 93                                                NaN     NaN
# 94                                                NaN     NaN
# 95                                                NaN     NaN
# 96                                                NaN     NaN
#
#                                                    9               10   11  \
# 0   2-letter codes used by the United States Coast...  Abbreviations:  GPO
# 1                                                 NaN             NaN  NaN
# 2                                                 NaN             NaN  NaN
# 3                                                 NaN             NaN  NaN
# 4                                                 NaN             NaN  NaN
# 5                                                 NaN             NaN  NaN
# 6                                                 NaN             NaN  NaN
# 7                                                 NaN             NaN  NaN
# 8                                                 NaN             NaN  NaN
# 9                                                 NaN             NaN  NaN
# 10                                                NaN             NaN  NaN
# 11                                             U.S.A.             NaN  NaN
# 12                                                NaN             NaN  NaN
# 13                                              Alas.             NaN  NaN
# 14                                                Az.             NaN  NaN
# 15                                                NaN             NaN  NaN
# 16                                          Ca., Cal.             NaN  NaN
# 17                                               Col.             NaN  NaN
# 18                                                Ct.             NaN  NaN
# 19                                                De.             NaN  NaN
# 20                                         Wash. D.C.             NaN  NaN
# 21                                         Fl., Flor.             NaN  NaN
# 22                                               Geo.             NaN  NaN
# 23                                               H.I.             NaN  NaN
# 24                                          Id., Ida.             NaN  NaN
# 25                                  Il., Ills., Ill's             NaN  NaN
# 26                                                In.             NaN  NaN
# 27                                       Ia., Ioa.[a]             NaN  NaN
# 28                                           Ks., Ka.             NaN  NaN
# 29                                     Ken., Kent.[b]             NaN  NaN
# ..                                                ...             ...  ...
# 67                                           U.S.V.I.             NaN  NaN
# 68                                                NaN             NaN  NaN
# 69                                              XB[3]             NaN  NaN
# 70                                              XH[3]             NaN  NaN
# 71                                              XQ[3]             NaN  NaN
# 72                                              XU[3]             NaN  NaN
# 73                                              XM[3]             NaN  NaN
# 74                                              QM[3]             NaN  NaN
# 75                                              XV[3]             NaN  NaN
# 76                                              XL[3]             NaN  NaN
# 77                                              QW[3]             NaN  NaN
# 78                                                NaN             NaN  NaN
# 79                                                NaN             NaN  NaN
# 80                                                NaN             NaN  NaN
# 81                                                NaN             NaN  NaN
# 82                                                NaN             NaN  NaN
# 83                                                NaN             NaN  NaN
# 84                                                NaN             NaN  NaN
# 85                                                NaN             NaN  NaN
# 86                                                NaN             NaN  NaN
# 87                                                NaN             NaN  NaN
# 88                                                NaN             NaN  NaN
# 89                                                NaN             NaN  NaN
# 90                                                NaN             NaN  NaN
# 91                                                NaN             NaN  NaN
# 92                                                NaN             NaN  NaN
# 93                                                NaN             NaN  NaN
# 94                                                NaN             NaN  NaN
# 95                                                NaN             NaN  NaN
# 96                                                NaN             NaN  NaN
#
#                                                    12   13  \
# 0   Older variable-length official US Government P...   AP
# 1                                                 NaN  NaN
# 2                                                 NaN  NaN
# 3                                                 NaN  NaN
# 4                                                 NaN  NaN
# 5                                                 NaN  NaN
# 6                                                 NaN  NaN
# 7                                                 NaN  NaN
# 8                                                 NaN  NaN
# 9                                                 NaN  NaN
# 10                                                NaN  NaN
# 11                                                NaN  NaN
# 12                                                NaN  NaN
# 13                                                NaN  NaN
# 14                                                NaN  NaN
# 15                                                NaN  NaN
# 16                                                NaN  NaN
# 17                                                NaN  NaN
# 18                                                NaN  NaN
# 19                                                NaN  NaN
# 20                                                NaN  NaN
# 21                                                NaN  NaN
# 22                                                NaN  NaN
# 23                                                NaN  NaN
# 24                                                NaN  NaN
# 25                                                NaN  NaN
# 26                                                NaN  NaN
# 27                                                NaN  NaN
# 28                                                NaN  NaN
# 29                                                NaN  NaN
# ..                                                ...  ...
# 67                                                NaN  NaN
# 68                                                NaN  NaN
# 69                                                NaN  NaN
# 70                                                NaN  NaN
# 71                                                NaN  NaN
# 72                                                NaN  NaN
# 73                                                NaN  NaN
# 74                                                NaN  NaN
# 75                                                NaN  NaN
# 76                                                NaN  NaN
# 77                                                NaN  NaN
# 78                                                NaN  NaN
# 79                                                NaN  NaN
# 80                                                NaN  NaN
# 81                                                NaN  NaN
# 82                                                NaN  NaN
# 83                                                NaN  NaN
# 84                                                NaN  NaN
# 85                                                NaN  NaN
# 86                                                NaN  NaN
# 87                                                NaN  NaN
# 88                                                NaN  NaN
# 89                                                NaN  NaN
# 90                                                NaN  NaN
# 91                                                NaN  NaN
# 92                                                NaN  NaN
# 93                                                NaN  NaN
# 94                                                NaN  NaN
# 95                                                NaN  NaN
# 96                                                NaN  NaN
#
#                                                    14
# 0   Abbreviations from the AP Stylebook (red text ...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
# 70                                                NaN
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
# 91                                                NaN
# 92                                                NaN
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
#
# [97 rows x 15 columns]

# %%
df1.drop(df.head(11).index, inplace=True)
df1
# Out:
#                                         0   \
# 11                United States of America
# 12                                 Alabama
# 13                                  Alaska
# 14                                 Arizona
# 15                                Arkansas
# 16                              California
# 17                                Colorado
# 18                             Connecticut
# 19                                Delaware
# 20                    District of Columbia
# 21                                 Florida
# 22                                 Georgia
# 23                                  Hawaii
# 24                                   Idaho
# 25                                Illinois
# 26                                 Indiana
# 27                                    Iowa
# 28                                  Kansas
# 29                                Kentucky
# 30                               Louisiana
# 31                                   Maine
# 32                                Maryland
# 33                           Massachusetts
# 34                                Michigan
# 35                               Minnesota
# 36                             Mississippi
# 37                                Missouri
# 38                                 Montana
# 39                                Nebraska
# 40                                  Nevada
# ..                                     ...
# 67                     U.S. Virgin Islands
# 68             U.S. Minor Outlying Islands
# 69                            Baker Island
# 70                          Howland Island
# 71                           Jarvis Island
# 72                          Johnston Atoll
# 73                            Kingman Reef
# 74                          Midway Islands
# 75                          Navassa Island
# 76                        Palmyra Atoll[c]
# 77                             Wake Island
# 78                              Micronesia
# 79                        Marshall Islands
# 80                                   Palau
# 81         U.S. Armed Forces – Americas[d]
# 82           U.S. Armed Forces – Europe[e]
# 83          U.S. Armed Forces – Pacific[f]
# 84                Northern Mariana Islands
# 85                       Panama Canal Zone
# 86                                Nebraska
# 87                      Philippine Islands
# 88  Trust Territory of the Pacific Islands
# 89                                  Codes:
# 90                                     ISO
# 91                                    ANSI
# 92                                    USPS
# 93                                    USCG
# 94                          Abbreviations:
# 95                                     GPO
# 96                                      AP
#
#                                                    1   \
# 11                                      Federal state
# 12                                              State
# 13                                              State
# 14                                              State
# 15                                              State
# 16                                              State
# 17                                              State
# 18                                              State
# 19                                              State
# 20                                   Federal district
# 21                                              State
# 22                                              State
# 23                                              State
# 24                                              State
# 25                                              State
# 26                                              State
# 27                                              State
# 28                                              State
# 29                               State (Commonwealth)
# 30                                              State
# 31                                              State
# 32                                              State
# 33                               State (Commonwealth)
# 34                                              State
# 35                                              State
# 36                                              State
# 37                                              State
# 38                                              State
# 39                                              State
# 40                                              State
# ..                                                ...
# 67                           Insular area (Territory)
# 68                                      Insular areas
# 69                                             island
# 70                                             island
# 71                                             island
# 72                                              atoll
# 73                                              atoll
# 74                                              atoll
# 75                                             island
# 76                                           atoll[c]
# 77                                              atoll
# 78                            Freely associated state
# 79                            Freely associated state
# 80                            Freely associated state
# 81                              US military mail code
# 82                              US military mail code
# 83                              US military mail code
# 84                            Obsolete postal code[g]
# 85                               Obsolete postal code
# 86                            Obsolete postal code[h]
# 87                               Obsolete postal code
# 88                               Obsolete postal code
# 89                                                NaN
# 90  ISO 3166 codes (2-letter, 3-letter, and 3-digi...
# 91  2-letter and 2-digit codes from the ANSI stand...
# 92  2-letter codes used by the United States Posta...
# 93  2-letter codes used by the United States Coast...
# 94                                                NaN
# 95  Older variable-length official US Government P...
# 96  Abbreviations from the AP Stylebook (red text ...
#
#                                                    2    3    4    5    6   \
# 11  .mw-parser-output .monospaced{font-family:mono...   US   00  NaN  NaN
# 12                                              US-AL   AL   01   AL   AL
# 13                                              US-AK   AK   02   AK   AK
# 14                                              US-AZ   AZ   04   AZ   AZ
# 15                                              US-AR   AR   05   AR   AR
# 16                                              US-CA   CA   06   CA   CF
# 17                                              US-CO   CO   08   CO   CL
# 18                                              US-CT   CT   09   CT   CT
# 19                                              US-DE   DE   10   DE   DL
# 20                                              US-DC   DC   11   DC   DC
# 21                                              US-FL   FL   12   FL   FL
# 22                                              US-GA   GA   13   GA   GA
# 23                                              US-HI   HI   15   HI   HA
# 24                                              US-ID   ID   16   ID   ID
# 25                                              US-IL   IL   17   IL   IL
# 26                                              US-IN   IN   18   IN   IN
# 27                                              US-IA   IA   19   IA   IA
# 28                                              US-KS   KS   20   KS   KA
# 29                                              US-KY   KY   21   KY   KY
# 30                                              US-LA   LA   22   LA   LA
# 31                                              US-ME   ME   23   ME   ME
# 32                                              US-MD   MD   24   MD   MD
# 33                                              US-MA   MA   25   MA   MS
# 34                                              US-MI   MI   26   MI   MC
# 35                                              US-MN   MN   27   MN   MN
# 36                                              US-MS   MS   28   MS   MI
# 37                                              US-MO   MO   29   MO   MO
# 38                                              US-MT   MT   30   MT   MT
# 39                                              US-NE   NE   31   NE   NB
# 40                                              US-NV   NV   32   NV   NV
# ..                                                ...  ...  ...  ...  ...
# 67                                      VIVIR850US-VI   VI   78   VI   VI
# 68                                      UMUMI581US-UM   UM   74  NaN  NaN
# 69                                              UM-81  NaN   81  NaN  NaN
# 70                                              UM-84  NaN   84  NaN  NaN
# 71                                              UM-86  NaN   86  NaN  NaN
# 72                                              UM-67  NaN   67  NaN  NaN
# 73                                              UM-89  NaN   89  NaN  NaN
# 74                                              UM-71  NaN   71  NaN  NaN
# 75                                              UM-76  NaN   76  NaN  NaN
# 76                                              UM-95  NaN   95  NaN  NaN
# 77                                              UM-79  NaN   79  NaN  NaN
# 78                                           FMFSM583   FM   64   FM  NaN
# 79                                           MHMHL584   MH   68   MH  NaN
# 80                                           PWPLW585   PW   70   PW  NaN
# 81                                                NaN  NaN  NaN   AA  NaN
# 82                                                NaN  NaN  NaN   AE  NaN
# 83                                                NaN  NaN  NaN   AP  NaN
# 84                                                NaN  NaN  NaN   CM  NaN
# 85                                           PZPCZ594  NaN  NaN   CZ  NaN
# 86                                                NaN  NaN  NaN   NB  NaN
# 87                                        PHPHL608[4]  NaN  NaN   PI  NaN
# 88                                           PCPCI582  NaN  NaN   TT  NaN
# 89                                                NaN  NaN  NaN  NaN  NaN
# 90                                                NaN  NaN  NaN  NaN  NaN
# 91                                                NaN  NaN  NaN  NaN  NaN
# 92                                                NaN  NaN  NaN  NaN  NaN
# 93                                                NaN  NaN  NaN  NaN  NaN
# 94                                                NaN  NaN  NaN  NaN  NaN
# 95                                                NaN  NaN  NaN  NaN  NaN
# 96                                                NaN  NaN  NaN  NaN  NaN
#
#         7       8                  9    10   11   12   13   14
# 11    U.S.    U.S.             U.S.A.  NaN  NaN  NaN  NaN  NaN
# 12    Ala.    Ala.                NaN  NaN  NaN  NaN  NaN  NaN
# 13  Alaska  Alaska              Alas.  NaN  NaN  NaN  NaN  NaN
# 14   Ariz.   Ariz.                Az.  NaN  NaN  NaN  NaN  NaN
# 15    Ark.    Ark.                NaN  NaN  NaN  NaN  NaN  NaN
# 16  Calif.  Calif.          Ca., Cal.  NaN  NaN  NaN  NaN  NaN
# 17   Colo.   Colo.               Col.  NaN  NaN  NaN  NaN  NaN
# 18   Conn.   Conn.                Ct.  NaN  NaN  NaN  NaN  NaN
# 19    Del.    Del.                De.  NaN  NaN  NaN  NaN  NaN
# 20    D.C.    D.C.         Wash. D.C.  NaN  NaN  NaN  NaN  NaN
# 21    Fla.    Fla.         Fl., Flor.  NaN  NaN  NaN  NaN  NaN
# 22     Ga.     Ga.               Geo.  NaN  NaN  NaN  NaN  NaN
# 23  Hawaii  Hawaii               H.I.  NaN  NaN  NaN  NaN  NaN
# 24   Idaho   Idaho          Id., Ida.  NaN  NaN  NaN  NaN  NaN
# 25    Ill.    Ill.  Il., Ills., Ill's  NaN  NaN  NaN  NaN  NaN
# 26    Ind.    Ind.                In.  NaN  NaN  NaN  NaN  NaN
# 27    Iowa    Iowa       Ia., Ioa.[a]  NaN  NaN  NaN  NaN  NaN
# 28   Kans.    Kan.           Ks., Ka.  NaN  NaN  NaN  NaN  NaN
# 29     Ky.     Ky.     Ken., Kent.[b]  NaN  NaN  NaN  NaN  NaN
# 30     La.     La.                NaN  NaN  NaN  NaN  NaN  NaN
# 31   Maine   Maine                Me.  NaN  NaN  NaN  NaN  NaN
# 32     Md.     Md.                NaN  NaN  NaN  NaN  NaN  NaN
# 33   Mass.   Mass.                NaN  NaN  NaN  NaN  NaN  NaN
# 34   Mich.   Mich.                NaN  NaN  NaN  NaN  NaN  NaN
# 35   Minn.   Minn.                Mn.  NaN  NaN  NaN  NaN  NaN
# 36   Miss.   Miss.                NaN  NaN  NaN  NaN  NaN  NaN
# 37     Mo.     Mo.                NaN  NaN  NaN  NaN  NaN  NaN
# 38   Mont.   Mont.                NaN  NaN  NaN  NaN  NaN  NaN
# 39   Nebr.    Neb.                NaN  NaN  NaN  NaN  NaN  NaN
# 40    Nev.    Nev.                Nv.  NaN  NaN  NaN  NaN  NaN
# ..     ...     ...                ...  ...  ...  ...  ...  ...
# 67    V.I.     NaN           U.S.V.I.  NaN  NaN  NaN  NaN  NaN
# 68     NaN     NaN                NaN  NaN  NaN  NaN  NaN  NaN
# 69     NaN     NaN              XB[3]  NaN  NaN  NaN  NaN  NaN
# 70     NaN     NaN              XH[3]  NaN  NaN  NaN  NaN  NaN
# 71     NaN     NaN              XQ[3]  NaN  NaN  NaN  NaN  NaN
# 72     NaN     NaN              XU[3]  NaN  NaN  NaN  NaN  NaN
# 73     NaN     NaN              XM[3]  NaN  NaN  NaN  NaN  NaN
# 74     NaN     NaN              QM[3]  NaN  NaN  NaN  NaN  NaN
# 75     NaN     NaN              XV[3]  NaN  NaN  NaN  NaN  NaN
# 76     NaN     NaN              XL[3]  NaN  NaN  NaN  NaN  NaN
# 77     NaN     NaN              QW[3]  NaN  NaN  NaN  NaN  NaN
# 78     NaN     NaN                NaN  NaN  NaN  NaN  NaN  NaN
# 79     NaN     NaN                NaN  NaN  NaN  NaN  NaN  NaN
# 80     NaN     NaN                NaN  NaN  NaN  NaN  NaN  NaN
# 81     NaN     NaN                NaN  NaN  NaN  NaN  NaN  NaN
# 82     NaN     NaN                NaN  NaN  NaN  NaN  NaN  NaN
# 83     NaN     NaN                NaN  NaN  NaN  NaN  NaN  NaN
# 84     NaN     NaN                NaN  NaN  NaN  NaN  NaN  NaN
# 85     NaN     NaN                NaN  NaN  NaN  NaN  NaN  NaN
# 86     NaN     NaN                NaN  NaN  NaN  NaN  NaN  NaN
# 87     NaN     NaN                NaN  NaN  NaN  NaN  NaN  NaN
# 88     NaN     NaN                NaN  NaN  NaN  NaN  NaN  NaN
# 89     NaN     NaN                NaN  NaN  NaN  NaN  NaN  NaN
# 90     NaN     NaN                NaN  NaN  NaN  NaN  NaN  NaN
# 91     NaN     NaN                NaN  NaN  NaN  NaN  NaN  NaN
# 92     NaN     NaN                NaN  NaN  NaN  NaN  NaN  NaN
# 93     NaN     NaN                NaN  NaN  NaN  NaN  NaN  NaN
# 94     NaN     NaN                NaN  NaN  NaN  NaN  NaN  NaN
# 95     NaN     NaN                NaN  NaN  NaN  NaN  NaN  NaN
# 96     NaN     NaN                NaN  NaN  NaN  NaN  NaN  NaN
#
# [86 rows x 15 columns]

# %% [markdown]
# # Mapping Countries to their abbreviations
#
# Using the data scraped from the previous task, map abbriviation to the name of states.
#
#
#
# ## Instructions:
#
# - Using the scraped data create a variable called `mapping` which has the Country
#  as key and Abbreviation as value
# - Create a new column called `abbr` as the 7th column (index = 6) of the DataFrame `df_final`
# - map the `df_final['state']` on variable `mapping` and store it in `df_final['abbr']`

# %%
# Code Starts here
import numpy as np
mapping = dict(zip(df1[0].str.lower(), df1[5]))
mapping
df_final['abbr']=''

# Code ends here

# %%
print(mapping)
df_final['abbr']=pd.Series(df_final['state']).map(mapping)
df_final
# Out:
# {'united states of america': nan, 'alabama': 'AL', 'alaska': 'AK', 'arizona': 'AZ', 'arkansas': 'AR', 'california': 'CA', 'colorado': 'CO', 'connecticut': 'CT', 'delaware': 'DE', 'district of columbia': 'DC', 'florida': 'FL', 'georgia': 'GA', 'hawaii': 'HI', 'idaho': 'ID', 'illinois': 'IL', 'indiana': 'IN', 'iowa': 'IA', 'kansas': 'KS', 'kentucky': 'KY', 'louisiana': 'LA', 'maine': 'ME', 'maryland': 'MD', 'massachusetts': 'MA', 'michigan': 'MI', 'minnesota': 'MN', 'mississippi': 'MS', 'missouri': 'MO', 'montana': 'MT', 'nebraska': 'NB', 'nevada': 'NV', 'new hampshire': 'NH', 'new jersey': 'NJ', 'new mexico': 'NM', 'new york': 'NY', 'north carolina': 'NC', 'north dakota': 'ND', 'ohio': 'OH', 'oklahoma': 'OK', 'oregon': 'OR', 'pennsylvania': 'PA', 'rhode island': 'RI', 'south carolina': 'SC', 'south dakota': 'SD', 'tennessee': 'TN', 'texas': 'TX', 'utah': 'UT', 'vermont': 'VT', 'virginia': 'VA', 'washington': 'WA', 'west virginia': 'WV', 'wisconsin': 'WI', 'wyoming': 'WY', 'american samoa': 'AS', 'guam': 'GU', 'northern mariana islands': 'CM', 'puerto rico': 'PR', 'u.s. virgin islands': 'VI', 'u.s. minor outlying islands': nan, 'baker island': nan, 'howland island': nan, 'jarvis island': nan, 'johnston atoll': nan, 'kingman reef': nan, 'midway islands': nan, 'navassa island': nan, 'palmyra atoll[c]': nan, 'wake island': nan, 'micronesia': 'FM', 'marshall islands': 'MH', 'palau': 'PW', 'u.s. armed forces – americas[d]': 'AA', 'u.s. armed forces – europe[e]': 'AE', 'u.s. armed forces – pacific[f]': 'AP', 'panama canal zone': 'CZ', 'philippine islands': 'PI', 'trust territory of the pacific islands': 'TT', 'codes:': nan, 'iso': nan, 'ansi': nan, 'usps': nan, 'uscg': nan, 'abbreviations:': nan, 'gpo': nan, 'ap': nan}
#      account                              name  \
# 0   211829.0        Kerluke, Koepp and Hilpert
# 1   320563.0                    Walter-Trantow
# 2   648336.0        Bashirian, Kunde and Price
# 3   109996.0       D'Amore, Gleichner and Bode
# 4   121213.0                     Bauch-Goldner
# 5   132971.0  Williamson, Schumm and Hettinger
# 6   145068.0                        Casper LLC
# 7   205217.0                  Kovacek-Johnston
# 8   209744.0                    Champlin-Morar
# 9   212303.0                    Gerhold-Maggio
# 10  214098.0       Goodwin, Homenick and Jerde
# 11  231907.0                        Hahn-Moore
# 12  242368.0      Frami, Anderson and Donnelly
# 13  268755.0                       Walsh-Haley
# 14  273274.0                     McDermott PLC
# 15       NaN                               NaN
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          texas
# 1                      1311 Alvis Tunnel      Port Khadijah  northcarolina
# 2   62184 Schamberger Underpass Apt. 231     New Lilianland           iowa
# 3            155 Fadel Crescent Apt. 144         Hyattburgh          maine
# 4                    7274 Marissa Common    Shanahanchester     california
# 5                   89403 Casimer Spring       Jeremieburgh       arkansas
# 6           340 Consuela Bridge Apt. 400  Lake Gabriellaton     mississipi
# 7           91971 Cronin Vista Suite 601         Deronville    rhodeisland
# 8                       26739 Grant Lock    Lake Juliannton   pennsylvania
# 9              366 Maggio Grove Apt. 998          North Ras          idaho
# 10             649 Cierra Forks Apt. 078           Rosaberg       tenessee
# 11              18115 Olivine Throughway      Norbertomouth    northdakota
# 12                       182 Bertie Road        East Davian           iowa
# 13                  2624 Beatty Parkways       Goodwinmouth    rhodeisland
# 14                 8917 Bergstrom Meadow    Kathryneborough       delaware
# 15                                   NaN                NaN            NaN
#
#     postal-code      Jan      Feb     Mar    total abbr
# 0       28752.0    10000    62000   35000   107000   TX
# 1       38365.0    95000    45000   35000   175000  NaN
# 2       76517.0    91000   120000   35000   246000   IA
# 3       46021.0    45000   120000   10000   175000   ME
# 4       49681.0   162000   120000   35000   317000   CA
# 5       62785.0   150000   120000   35000   305000   AR
# 6       18008.0    62000   120000   70000   252000  NaN
# 7       53461.0   145000    95000   35000   275000  NaN
# 8       64415.0    70000    95000   35000   200000   PA
# 9       46308.0    70000   120000   35000   225000   ID
# 10      47743.0    45000   120000   55000   220000  NaN
# 11      31415.0   150000    10000  162000   322000  NaN
# 12      72686.0   162000   120000   35000   317000   IA
# 13      31919.0    55000   120000   35000   210000  NaN
# 14      27933.0   150000   120000   70000   340000   DE
# 15          NaN  1507000  1507000  717000  3686000  NaN

# %% [markdown]
# # Filling in the Missing Values
#
# What you will notice in the previous task is that for two states Mississippi and Tennessee will have NaN values in column `abbr`. In this task you will be filling those missing values manually.
#
#
#
# ## Intructions :
# - Locate the NaN in the abbr and replace `mississipi` with `MS` and store it in `df_mississipi`
# - Locate the NaN in the abbr and replace `tenessee` with `TN` and store it in `df_tenessee`
# - update the df_final

# %%
# Code starts here

df_final['abbr'][df_final.state == "mississipi"] = "MS"
df_final['abbr'][df_final.state == "tenessee"] = "TN"
df_final
# Code ends here
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#      account                              name  \
# 0   211829.0        Kerluke, Koepp and Hilpert
# 1   320563.0                    Walter-Trantow
# 2   648336.0        Bashirian, Kunde and Price
# 3   109996.0       D'Amore, Gleichner and Bode
# 4   121213.0                     Bauch-Goldner
# 5   132971.0  Williamson, Schumm and Hettinger
# 6   145068.0                        Casper LLC
# 7   205217.0                  Kovacek-Johnston
# 8   209744.0                    Champlin-Morar
# 9   212303.0                    Gerhold-Maggio
# 10  214098.0       Goodwin, Homenick and Jerde
# 11  231907.0                        Hahn-Moore
# 12  242368.0      Frami, Anderson and Donnelly
# 13  268755.0                       Walsh-Haley
# 14  273274.0                     McDermott PLC
# 15       NaN                               NaN
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          texas
# 1                      1311 Alvis Tunnel      Port Khadijah  northcarolina
# 2   62184 Schamberger Underpass Apt. 231     New Lilianland           iowa
# 3            155 Fadel Crescent Apt. 144         Hyattburgh          maine
# 4                    7274 Marissa Common    Shanahanchester     california
# 5                   89403 Casimer Spring       Jeremieburgh       arkansas
# 6           340 Consuela Bridge Apt. 400  Lake Gabriellaton     mississipi
# 7           91971 Cronin Vista Suite 601         Deronville    rhodeisland
# 8                       26739 Grant Lock    Lake Juliannton   pennsylvania
# 9              366 Maggio Grove Apt. 998          North Ras          idaho
# 10             649 Cierra Forks Apt. 078           Rosaberg       tenessee
# 11              18115 Olivine Throughway      Norbertomouth    northdakota
# 12                       182 Bertie Road        East Davian           iowa
# 13                  2624 Beatty Parkways       Goodwinmouth    rhodeisland
# 14                 8917 Bergstrom Meadow    Kathryneborough       delaware
# 15                                   NaN                NaN            NaN
#
#     postal-code      Jan      Feb     Mar    total abbr
# 0       28752.0    10000    62000   35000   107000   TX
# 1       38365.0    95000    45000   35000   175000  NaN
# 2       76517.0    91000   120000   35000   246000   IA
# 3       46021.0    45000   120000   10000   175000   ME
# 4       49681.0   162000   120000   35000   317000   CA
# 5       62785.0   150000   120000   35000   305000   AR
# 6       18008.0    62000   120000   70000   252000   MS
# 7       53461.0   145000    95000   35000   275000  NaN
# 8       64415.0    70000    95000   35000   200000   PA
# 9       46308.0    70000   120000   35000   225000   ID
# 10      47743.0    45000   120000   55000   220000   TN
# 11      31415.0   150000    10000  162000   322000  NaN
# 12      72686.0   162000   120000   35000   317000   IA
# 13      31919.0    55000   120000   35000   210000  NaN
# 14      27933.0   150000   120000   70000   340000   DE
# 15          NaN  1507000  1507000  717000  3686000  NaN

# %% [markdown]
# ## Total amount bank hold
#
#
# Here, use the newly created abbr column to understand the total amount that the bank holds in each state. Let us make this data frame more readable by introducing units in this case `$` sign representing the unit of mone
#
#
#
# ## Instructions :
#
# - Groups by `abbr` and finds the sum of aabr,jan,feb ,mar and total store the result in `df_sub`
# - Write a `lambda function` to introduce `$` sign infromt of all the numbers using `applymap` and store the result in `formatted_df`

# %%
# Code starts here

df_sub=df_final.groupby('abbr')['Jan','Feb','Mar','total'].sum()
df_sub
formatted_df=df_sub.applymap("${0:.2f}".format)
formatted_df
# Code ends here
# Out:
#              Jan         Feb        Mar       total
# abbr
# AR    $150000.00  $120000.00  $35000.00  $305000.00
# CA    $162000.00  $120000.00  $35000.00  $317000.00
# DE    $150000.00  $120000.00  $70000.00  $340000.00
# IA    $253000.00  $240000.00  $70000.00  $563000.00
# ID     $70000.00  $120000.00  $35000.00  $225000.00
# ME     $45000.00  $120000.00  $10000.00  $175000.00
# MS     $62000.00  $120000.00  $70000.00  $252000.00
# PA     $70000.00   $95000.00  $35000.00  $200000.00
# TN     $45000.00  $120000.00  $55000.00  $220000.00
# TX     $10000.00   $62000.00  $35000.00  $107000.00

# %% [markdown]
# # Append a row to the DataFrame
#
# In this task, you will append a row to the data frame which will give us information about the total amount of the various regions in Jan, Feb and march and also the grand total
#
# ## Instructions :
#
# - Computes the sum of amount of all users in the Month of Jan, Feb, March and the  total in variable called `sum_row`
#  (Here the sum implies the sum of all the entries in the `Jan Column`, sum of entries in `Feb` Column and Grand total stands for the sum of entries in the column `total`)
# - Tranpose the dataframe `sum_row` and store it in new dataframe `df_sub_sum`
# - Make sure you append the `$` to all the digits and store it in dataframe `df_sub_sum` .
# - Append this computed sum to the DataFrame `final_table`
# - rename the index of `final_table` to  `{0: "Total"}`

# %%
# Code starts here
sum_row=df_final[["Jan","Feb","Mar","total"]].sum()
df_sub_sum=pd.DataFrame(sum_row).applymap("${0:.2f}".format)
df_sub_sum

# Code ends here
# Out:
#                  0
# Jan    $2969000.00
# Feb    $3014000.00
# Mar    $1434000.00
# total  $7372000.00

# %% [markdown]
# # Pie chart for total
#
#
# Having prepared all the data now its time to present the results visually
#
# ## Instructions :
# - add the total of all the three months and store it in variable called `df_sub['total']`
# - plot the pie chart for the `df_sub['total']`

# %%
# Code starts here
df_sub_total=df_sub[["total"]]
df_sub_total

fig=plt.figure(figsize=(10,7))
ax=plt.pie(df_sub_total,labels=df_sub_total.index,autopct="%.2f" )
plt.title("Pie Chart")
plt.legend(df_sub_total.index,loc="upper right")
plt.show()


# Code ends here
